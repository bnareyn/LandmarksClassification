jpg
#   inflating: landmark_images/train/18.Delicate_Arch/363e9884d1d21b8a.jpg
#   inflating: landmark_images/train/18.Delicate_Arch/2bece63c424609b2.jpg
#   inflating: landmark_images/train/18.Delicate_Arch/08995d3d708cd179.jpg
#   inflating: landmark_images/train/18.Delicate_Arch/48b980d62a0ab556.jpg
#    creating: landmark_images/train/37.Atomium/
#   inflating: landmark_images/train/37.Atomium/2722f89270ac7e18.jpg
#   inflating: landmark_images/train/37.Atomium/010fa01c892286c6.jpg
#   inflating: landmark_images/train/37.Atomium/00e8bc8139bb8121.jpg
#   inflating: landmark_images/train/37.Atomium/26bba13cb454646a.jpg
#   inflating: landmark_images/train/37.Atomium/4169fa7d5435b4fb.jpg
#   inflating: landmark_images/train/37.Atomium/7607f8e1602ac55a.jpg
#   inflating: landmark_images/train/37.Atomium/1ad996e9232b4ac3.jpg
#   inflating: landmark_images/train/37.Atomium/7783db2db3ca5cfb.jpg
#   inflating: landmark_images/train/37.Atomium/762ae752dd983d4c.jpg
#   inflating: landmark_images/train/37.Atomium/6152aebe2cb32734.jpg
#   inflating: landmark_images/train/37.Atomium/7d8b1eb99361ccd5.jpg
#   inflating: landmark_images/train/37.Atomium/03a8e258cd091cad.jpg
#   inflating: landmark_images/train/37.Atomium/0c993510578209a4.jpg
#   inflating: landmark_images/train/37.Atomium/139dab84fa5dfe85.jpg
#   inflating: landmark_images/train/37.Atomium/17f1e608b9d97347.jpg
#   inflating: landmark_images/train/37.Atomium/45b442ef5ea32a19.jpg
#   inflating: landmark_images/train/37.Atomium/1f8248c265636a9c.jpg
#   inflating: landmark_images/train/37.Atomium/0a97e69092958d3f.jpg
#   inflating: landmark_images/train/37.Atomium/11a3c2a2255f01e3.jpg
#   inflating: landmark_images/train/37.Atomium/55fc4f97d10cd0cc.jpg
#   inflating: landmark_images/train/37.Atomium/196e2a7ee1efc13c.jpg
#   inflating: landmark_images/train/37.Atomium/2f72fdee3eeb4274.jpg
#   inflating: landmark_images/train/37.Atomium/0d6ae3c575f3cc9d.jpg
#   inflating: landmark_images/train/37.Atomium/243b837c74f3505e.jpg
#   inflating: landmark_images/train/37.Atomium/48c8f2bdb1e0f985.jpg
#   inflating: landmark_images/train/37.Atomium/060a5d436232217a.jpg
#   inflating: landmark_images/train/37.Atomium/368a9c8684673881.jpg
#   inflating: landmark_images/train/37.Atomium/6250f5380ac860b1.jpg
#   inflating: landmark_images/train/37.Atomium/416a960edf11dea7.jpg
#   inflating: landmark_images/train/37.Atomium/1c97ad502b3f5a9c.jpg
#   inflating: landmark_images/train/37.Atomium/5530c03fba4ec412.jpg
#   inflating: landmark_images/train/37.Atomium/34f510f9f752a641.jpg
#   inflating: landmark_images/train/37.Atomium/6cfc73d3fcc6bf02.jpg
#   inflating: landmark_images/train/37.Atomium/668671e673b441a3.jpg
#   inflating: landmark_images/train/37.Atomium/78597904eced85dc.jpg
#   inflating: landmark_images/train/37.Atomium/06b8191378d0291e.jpg
#   inflating: landmark_images/train/37.Atomium/59f5c2f496d28456.jpg
#   inflating: landmark_images/train/37.Atomium/30c9aad0ced3dbe1.jpg
#   inflating: landmark_images/train/37.Atomium/24d701ec158a72c3.jpg
#   inflating: landmark_images/train/37.Atomium/2bdb0e9c98850e6f.jpg
#   inflating: landmark_images/train/37.Atomium/116781791fdf9aae.jpg
#   inflating: landmark_images/train/37.Atomium/490443d4fac744ba.jpg
#   inflating: landmark_images/train/37.Atomium/6fcdbf1495ffce53.jpg
#   inflating: landmark_images/train/37.Atomium/3daeb0bf75dcc4ca.jpg
#   inflating: landmark_images/train/37.Atomium/1a3292544b924469.jpg
#   inflating: landmark_images/train/37.Atomium/76644a4cc4061d5f.jpg
#   inflating: landmark_images/train/37.Atomium/4bdb3c1105240bb1.jpg
#   inflating: landmark_images/train/37.Atomium/4e54cb91f3a58100.jpg
#   inflating: landmark_images/train/37.Atomium/6d1ce299a9c0334d.jpg
#   inflating: landmark_images/train/37.Atomium/54551c7fa9563a0f.jpg
#   inflating: landmark_images/train/37.Atomium/3ef2057b406c7d01.jpg
#   inflating: landmark_images/train/37.Atomium/52c345718045cd39.jpg
#   inflating: landmark_images/train/37.Atomium/75eec773894a942f.jpg
#   inflating: landmark_images/train/37.Atomium/21bdcc2f31b85415.jpg
#   inflating: landmark_images/train/37.Atomium/58d745d12b4e98b3.jpg
#   inflating: landmark_images/train/37.Atomium/39fe1a33797cf2a2.jpg
#   inflating: landmark_images/train/37.Atomium/1b1e984bfde77b8e.jpg
#   inflating: landmark_images/train/37.Atomium/01f205c410f407a1.jpg
#   inflating: landmark_images/train/37.Atomium/3fb27ee3881dc10d.jpg
#   inflating: landmark_images/train/37.Atomium/680d30325c37814b.jpg
#   inflating: landmark_images/train/37.Atomium/5dcc92fbba3399f2.jpg
#   inflating: landmark_images/train/37.Atomium/1ca8f858165c5358.jpg
#   inflating: landmark_images/train/37.Atomium/2d34215bb7afc316.jpg
#   inflating: landmark_images/train/37.Atomium/2595a176390f4c91.jpg
#   inflating: landmark_images/train/37.Atomium/40463b4518c77132.jpg
#   inflating: landmark_images/train/37.Atomium/6e33a1241f86c4ac.jpg
#   inflating: landmark_images/train/37.Atomium/794de8f5402de243.jpg
#   inflating: landmark_images/train/37.Atomium/732c17b24df28b9a.jpg
#   inflating: landmark_images/train/37.Atomium/3888d4b2310d2dce.jpg
#   inflating: landmark_images/train/37.Atomium/4a134abfcaf88884.jpg
#   inflating: landmark_images/train/37.Atomium/78b93e83c4a37517.jpg
#   inflating: landmark_images/train/37.Atomium/3ac6e729706311ea.jpg
#   inflating: landmark_images/train/37.Atomium/4233c48e4affe62c.jpg
#   inflating: landmark_images/train/37.Atomium/0b33c3b4018dae8a.jpg
#   inflating: landmark_images/train/37.Atomium/0d52df632824eb91.jpg
#   inflating: landmark_images/train/37.Atomium/265838de3fe36d9e.jpg
#   inflating: landmark_images/train/37.Atomium/45e3cf965c425e27.jpg
#   inflating: landmark_images/train/37.Atomium/6e87aca072d80edd.jpg
#   inflating: landmark_images/train/37.Atomium/0100b8bb74c4c723.jpg
jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/30c98fa92c2d3f45.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/36635b5b03065100.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/4a7a2251709dbffe.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/407ef79dcbfd7197.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/6e284fa0c1cd3ad7.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/702c8a0d10c5a5f4.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/2a4e4eb134151bfe.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/65d70708b4d1aa70.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/7d3e6eafd67c4086.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/3cf4cea7c02dcc97.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/3eebb80c7301dfb2.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/1a18cb88278a7340.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/64db0ba098ea9bb7.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/332d8efdfbbef137.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/652bee0411676615.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/228fcad99980393f.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/0399832c09134a72.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/584257bdafa45890.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/7f83490c02eeea32.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/799611869d11b37a.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/199d32a4700318fb.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/73641b1b40b5819e.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/15f8eea6e261745a.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/5cba0c9f6bad2478.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/1537ea690f8915b3.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/52c480ed95a46209.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/468928f0ff814af1.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/276da5dd46e47dce.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/7541234c71b2222c.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/372dd49470fa60d4.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/063fd92c7b7a3e79.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/702304765b549a86.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/0ab23fe58c072ef0.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/2042425ddb7a9a4a.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/2e802798cdb6c78e.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/31dfa8ab93742a82.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/424f821a5398cf9e.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/5ab653dead8a18c1.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/330b91a7436b077e.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/7822f872a8a58204.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/01f608e3ffcf3376.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/153360e5da097bfe.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/729f519b1419e20e.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/43b9c1fb8b966bcb.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/3cd9e20814fe39a7.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/62618f3ecece44d6.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/16a2babed17514e6.jpg
#   inflating: landmark_images/train/12.Kantanagar_Temple/076f5246089e33ff.jpg

# %% [markdown]
# ---
#
# <a id='step1'></a>
# ## Step 1: Create a CNN to Classify Landmarks (from Scratch)
#
# In this step, you will create a CNN that classifies landmarks.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 20%.
#
# Although 20% may seem low at first glance, it seems more reasonable after realizing how difficult of a problem this is. Many times, an image that is taken at a landmark captures a fairly mundane image of an animal or plant, like in the following picture.
#
# <img src="https://github.com/bnareyn/LandmarksClassification/blob/main/images/train/00.Haleakala_National_Park/084c2aa50d0a9249.jpg?raw=1" alt="Bird in Haleakalā National Park" style="width: 400px;"/>
#
# Just by looking at that image alone, would you have been able to guess that it was taken at the Haleakalā National Park in Hawaii?
#
# An accuracy of 20% is significantly better than random guessing, which would provide an accuracy of just 2%. In Step 2 of this notebook, you will have the opportunity to greatly improve accuracy by using transfer learning to create a CNN.
#
# Remember that practice is far ahead of theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!

# %% [markdown]
# ### (IMPLEMENTATION) Specify Data Loaders for the Landmark Dataset
#
# Use the code cell below to create three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader): one for training data, one for validation data, and one for test data. Randomly split the images located at `landmark_images/train` to create the train and validation data loaders, and use the images located at `landmark_images/test` to create the test data loader.
#
# **Note**: Remember that the dataset can be found at `/data/landmark_images/` in the workspace.
#
# All three of your data loaders should be accessible via a dictionary named `loaders_scratch`. Your train data loader should be at `loaders_scratch['train']`, your validation data loader should be at `loaders_scratch['valid']`, and your test data loader should be at `loaders_scratch['test']`.
#
# You may find [this documentation on custom datasets](https://pytorch.org/docs/stable/torchvision/datasets.html#datasetfolder) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ### Annotate

# %%
train_dir = "landmark_images/train"
data = [{'folder' : folder, 'file' : file, 'class' : str(idx)} for idx, folder in enumerate(sorted(os.listdir(train_dir))) for file in os.listdir( os.path.join(train_dir, folder)) ]
annotatedDF = pd.DataFrame(data = data, columns = ['folder', 'file', 'class'])
annotatedDF['classname'] = annotatedDF['folder'].apply(lambda x : x.split('.')[1].replace("_", " "))
annotatedDF.to_csv('annotated_train.csv', index = False)
labelMap = { str(idx) : folder.split('.')[1].replace("_", " ") for idx, folder in enumerate(sorted(os.listdir(train_dir)))}

# %%
train_dir = "landmark_images/test"
data = [{'folder' : folder, 'file' : file, 'class' : str(idx)} for idx, folder in enumerate(sorted(os.listdir(train_dir))) for file in os.listdir( os.path.join(train_dir, folder)) ]
annotatedDF = pd.DataFrame(data = data, columns = ['folder', 'file', 'class'])
annotatedDF['classname'] = annotatedDF['folder'].apply(lambda x : x.split('.')[1].replace("_", " "))
annotatedDF.to_csv('annotated_test.csv', index = False)

# %%
import cv2
import PIL

import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision import transforms

# %%
class LandmarksDataset(Dataset):
    def __init__(self, annotations_file, root = "landmark_images", train = True, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        if train:
            img_dir = "train"
        else:
            img_dir = "test"
        
        self.img_dir = os.path.join(root, img_dir)
            
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.loc[idx, 'folder'], self.img_labels.loc[idx, 'file'])
        image = cv2.imread(img_path)
        
        label = self.img_labels.loc[idx, 'class']
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        
        return image, label

# %%
### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

### Borrowing code from CIFAR classification notebook for train-valid-test split

from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0

# how many samples per batch to load
batch_size = 20

# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    #transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip(),
    transforms.Resize(300),
    transforms.RandomCrop(256),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Train and test datasets
train_data = LandmarksDataset('annotated_train.csv', train = True, transform=transform)
test_data  = LandmarksDataset('annotated_test.csv', train = False, transform=transform)

### Borrowing code from CIFAR classification notebook for train-valid-test split

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

loaders_scratch = {
    'train': train_loader, 
    'valid': valid_loader, 
    'test': test_loader
}

# %% [markdown]
# **Question 1:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:
# * Images are of varying sizes; the sizes are like (600, 800, 3), (480, 640, 3), (800, 600, 3), (519, 800, 3), (471, 800, 3), etc. The classification task is not for objects; but for places. So the largest possible center crop is needed to capture as much patterns as possible. I chose to go with (500, 500).
#
# * flips, translations

# %% [markdown]
# ### (IMPLEMENTATION) Visualize a Batch of Training Data
#
# Use the code cell below to retrieve a batch of images from your train data loader, display at least 5 images simultaneously, and label each displayed image with its class name (e.g., "Golden Gate Bridge").
#
# Visualizing the output of your data loader is a great way to ensure that your data loading and preprocessing are working as expected.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

## TODO: visualize a batch of the train data loader
# Borrowing a few lines of code from CIFAR CNN notebook

def imshow(img):
    img = img / 2 + 0.5 
    plt.imshow(np.transpose(img, (1, 2, 0))) 
    
## the class names can be accessed at the `classes` attribute
## of your dataset object (e.g., `train_dataset.classes`)
train_iter = iter(train_loader)
images, labels = next(train_iter)
images = images.numpy()
labels = labels.numpy()

fig = plt.figure(figsize=(15, 4))

for idx in np.arange(10):
    ax = fig.add_subplot(2, 5, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(labelMap[str(labels[idx])])

# %% [markdown]
# ### Initialize use_cuda variable

# %%
# useful variable that tells us whether we should use the GPU
use_cuda = torch.cuda.is_available()

# %%
use_cuda
# Out:
# True

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and fill in the function `get_optimizer_scratch` below.

# %%
## TODO: select loss function

from torch import nn

criterion_scratch = nn.CrossEntropyLoss()

import torch.optim as optim

def get_optimizer_scratch(model):
    ## TODO: select and return an optimizer
    return optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify images of landmarks.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ## TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        ### Conv
        self.conv1 = nn.Conv2d(  3,  64, 5, padding=2)
        #self.conv2 = nn.Conv2d( 64, 128, 5, padding=2)
        #self.conv3 = nn.Conv2d(128, 256, 5, padding=2)
        #self.conv4 = nn.Conv2d(256, 128, 3, padding=1)
        #self.conv5 = nn.Conv2d(128,  64, 3, padding=1)
        self.conv6 = nn.Conv2d( 64,  32, 5, padding=2)
        ### Pool
        self.maxpool = nn.MaxPool2d(2, 2)
        ### FC
        self.fc1   = nn.Linear(64*64*32, 32*32)
        #self.fc2   = nn.Linear(32*32* 8, 32*32   )
        self.fc3   = nn.Linear(32*32   , 32* 4   )
        self.fc4   = nn.Linear(32* 4   , 50      )
        ### Dropout
        self.dropout = nn.Dropout(0.10)
        
    
    def forward(self, x):
        ## Define forward behavior
        ### Conv
        #################### 512 x 512 x   3
        # 256 x 256 x 3 
        #print(x.shape)
        #print(x.dtype)
        x = F.relu(self.conv1(x))
        #print(x.shape)
        #################### 512 x 512 x  64
        # 256 x 256 x 64
        #x = F.relu(self.conv2(x))
        #################### 512 x 512 x 128
        # 256 x 256 x 128
        # max pool
        x = self.maxpool(x)
        #print(x.shape)
        #################### 256 x 256 x 128
        # 128 x 128 x 128
        #x = F.relu(self.conv3(x))
        #################### 256 x 256 x 256
        # maxpool
        #x = self.maxpool(x)
        #################### 128 x 128 x 256
        #x = F.relu(self.conv4(x))
        #################### 128 x 128 x 128
        #x = F.relu(self.conv5(x))
        # 128 x 128 x 64
        # max pool
        #x = self.maxpool(x)
        # 64 x  64 x  64
        x = F.relu(self.conv6(x))
        #print(x.shape)
        # 64 x  64 x  32
        # maxpool 
        x = self.maxpool(x)
        #print(x.shape)
        #print(x.shape)
        ####################  32 x  32 x  32
        ### FC
        # flatten
        x = x.view(-1, 64*64*32)
        x = self.dropout(x)
        # linear
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        # linear
        #x = F.relu(self.fc2(x))
        #x = self.dropout(x)
        # linear
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        # linear
        x = F.relu(self.fc4(x))
        
        return x

#-#-# Do NOT modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()
    
model_scratch
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv6): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=131072, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=50, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# __Question 2:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Implement the Training Algorithm
#
# Implement your training algorithm in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at the filepath stored in the variable `save_path`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        # set the module to training mode
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            ## TODO: find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data.item() - train_loss))
            
            ### Step 1 - Clear gradients. Don't let them accumulate
            optimizer.zero_grad()
            ### Step 2 - forward pass
            output = model(data)
            ### Step 3 - Calculate batch loss
            loss = criterion(output, target)
            ### Step 4 - back propagate
            loss.backward()
            ### Step 5 - update weights
            optimizer.step()
            ### Step 6 - update training loss
            #train_loss += loss.item() / len(data)
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data.item() - train_loss))
            
        ######################    
        # validate the model #
        ######################
        # set the model to evaluation mode
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            ## TODO: update average validation loss 
            ### Step 1 - forward pass
            output = model(data)
            ### Step 2 - calculate batch loss
            loss = criterion(output, target)
            ### Step 3 - update validation loss
            #valid_loss += loss.item() / len(data)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data.item() - valid_loss))


        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))

        ## TODO: if the validation loss has decreased, save the model at the filepath stored in save_path
        if valid_loss <= valid_loss_min:
            print("Validation loss reduced from {:.6f} to {:.6f}".format(
            valid_loss_min,
            valid_loss))
            ### Save model to save_path
            torch.save(model.state_dict(), save_path)
            print("Model state saved.")
            ### Update minimum loss to new minimum
            valid_loss_min = valid_loss        
        
    return model

# %% [markdown]
# ### (IMPLEMENTATION) Experiment with the Weight Initialization
#
# Use the code cell below to define a custom weight initialization, and then train with your weight initialization for a few epochs. Make sure that neither the training loss nor validation loss is `nan`.
#
# Later on, you will be able to see how this compares to training with PyTorch's default weight initialization.

# %%
def custom_weight_init(m):
    ## TODO: implement a weight initialization strategy
    classname = m.__class__.__name__
    # Update linear layer weights
    if classname.find('Linear') != -1:
        # fan_in
        n = m.in_features
        y = 1.0 / np.sqrt(n)
        m.weight.data.normal_(mean = 0.0, std = y)
        m.bias.data.fill_(0)


#-#-# Do NOT modify the code below this line. #-#-#
    
model_scratch.apply(custom_weight_init)
model_scratch = train(20, loaders_scratch, model_scratch, get_optimizer_scratch(model_scratch),
                      criterion_scratch, use_cuda, 'ignore.pt')
# Out:
# Epoch: 1 	Training Loss: 3.873121 	Validation Loss: 3.803718
# Validation loss reduced from inf to 3.803718
# Model state saved.
# Epoch: 2 	Training Loss: 3.799304 	Validation Loss: 3.795178
# Validation loss reduced from 3.803718 to 3.795178
# Model state saved.
# Epoch: 3 	Training Loss: 3.692429 	Validation Loss: 3.674905
# Validation loss reduced from 3.795178 to 3.674905
# Model state saved.
# Epoch: 4 	Training Loss: 3.623632 	Validation Loss: 3.691669
# Epoch: 5 	Training Loss: 3.552405 	Validation Loss: 3.542200
# Validation loss reduced from 3.674905 to 3.542200
# Model state saved.
# Epoch: 6 	Training Loss: 3.436164 	Validation Loss: 3.478540
# Validation loss reduced from 3.542200 to 3.478540
# Model state saved.
# Epoch: 7 	Training Loss: 3.360661 	Validation Loss: 3.398244
# Validation loss reduced from 3.478540 to 3.398244
# Model state saved.
# Epoch: 8 	Training Loss: 3.297520 	Validation Loss: 3.267028
# Validation loss reduced from 3.398244 to 3.267028
# Model state saved.
# Epoch: 9 	Training Loss: 3.188591 	Validation Loss: 3.326072
# Epoch: 10 	Training Loss: 3.129027 	Validation Loss: 3.209634
# Validation loss reduced from 3.267028 to 3.209634
# Model state saved.
# Epoch: 11 	Training Loss: 3.035260 	Validation Loss: 3.182305
# Validation loss reduced from 3.209634 to 3.182305
# Model state saved.
# Epoch: 12 	Training Loss: 2.973991 	Validation Loss: 3.137876
# Validation loss reduced from 3.182305 to 3.137876
# Model state saved.
# Epoch: 13 	Training Loss: 2.896093 	Validation Loss: 3.097559
# Validation loss reduced from 3.137876 to 3.097559
# Model state saved.
# Epoch: 14 	Training Loss: 2.863789 	Validation Loss: 2.943397
# Validation loss reduced from 3.097559 to 2.943397
# Model state saved.
# Epoch: 15 	Training Loss: 2.782052 	Validation Loss: 3.028912
# Epoch: 16 	Training Loss: 2.787643 	Validation Loss: 3.083789
# Epoch: 17 	Training Loss: 2.708797 	Validation Loss: 2.961460
# Epoch: 18 	Training Loss: 2.672201 	Validation Loss: 2.934805
# Validation loss reduced from 2.943397 to 2.934805
# Model state saved.
# Epoch: 19 	Training Loss: 2.616883 	Validation Loss: 2.990515
# Epoch: 20 	Training Loss: 2.566108 	Validation Loss: 2.904534
# Validation loss reduced from 2.934805 to 2.904534
# Model state saved.

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Run the next code cell to train your model.

# %%
## TODO: you may change the number of epochs if you'd like,
## but changing it is not required
num_epochs = 100

#-#-# Do NOT modify the code below this line. #-#-#

# function to re-initialize a model with pytorch's default weight initialization
def default_weight_init(m):
    reset_parameters = getattr(m, 'reset_parameters', None)
    if callable(reset_parameters):
        m.reset_parameters()

# reset the model parameters
model_scratch.apply(default_weight_init)

# train the model
model_scratch = train(num_epochs, loaders_scratch, model_scratch, get_optimizer_scratch(model_scratch), 
                      criterion_scratch, use_cuda, 'model_scratch.pt')
# Out:
# Epoch: 1 	Training Loss: 3.898775 	Validation Loss: 3.882179
# Validation loss reduced from inf to 3.882179
# Model state saved.
# Epoch: 2 	Training Loss: 3.807253 	Validation Loss: 3.746585
# Validation loss reduced from 3.882179 to 3.746585
# Model state saved.
# Epoch: 3 	Training Loss: 3.718912 	Validation Loss: 3.709020
# Validation loss reduced from 3.746585 to 3.709020
# Model state saved.
# Epoch: 4 	Training Loss: 3.660137 	Validation Loss: 3.638529
# Validation loss reduced from 3.709020 to 3.638529
# Model state saved.
# Epoch: 5 	Training Loss: 3.582976 	Validation Loss: 3.574794
# Validation loss reduced from 3.638529 to 3.574794
# Model state saved.
# Epoch: 6 	Training Loss: 3.502976 	Validation Loss: 3.526643
# Validation loss reduced from 3.574794 to 3.526643
# Model state saved.
# Epoch: 7 	Training Loss: 3.449992 	Validation Loss: 3.471717
# Validation loss reduced from 3.526643 to 3.471717
# Model state saved.
# Epoch: 8 	Training Loss: 3.344198 	Validation Loss: 3.487762
# Epoch: 9 	Training Loss: 3.285899 	Validation Loss: 3.439509
# Validation loss reduced from 3.471717 to 3.439509
# Model state saved.
# Epoch: 10 	Training Loss: 3.245263 	Validation Loss: 3.336835
# Validation loss reduced from 3.439509 to 3.336835
# Model state saved.
# Epoch: 11 	Training Loss: 3.142446 	Validation Loss: 3.205101
# Validation loss reduced from 3.336835 to 3.205101
# Model state saved.
# Epoch: 12 	Training Loss: 3.071438 	Validation Loss: 3.300420
# Epoch: 13 	Training Loss: 3.042191 	Validation Loss: 3.140090
# Validation loss reduced from 3.205101 to 3.140090
# Model state saved.
# Epoch: 14 	Training Loss: 2.918367 	Validation Loss: 3.094498
# Validation loss reduced from 3.140090 to 3.094498
# Model state saved.
# Epoch: 15 	Training Loss: 2.871807 	Validation Loss: 3.067719
# Validation loss reduced from 3.094498 to 3.067719
# Model state saved.
# Epoch: 16 	Training Loss: 2.845120 	Validation Loss: 3.077448
# Epoch: 17 	Training Loss: 2.800138 	Validation Loss: 3.030524
# Validation loss reduced from 3.067719 to 3.030524
# Model state saved.
# Epoch: 18 	Training Loss: 2.732727 	Validation Loss: 2.998582
# Validation loss reduced from 3.030524 to 2.998582
# Model state saved.
# Epoch: 19 	Training Loss: 2.713217 	Validation Loss: 3.067689
# Epoch: 20 	Training Loss: 2.607905 	Validation Loss: 2.876176
# Validation loss reduced from 2.998582 to 2.876176
# Model state saved.
# Epoch: 21 	Training Loss: 2.643766 	Validation Loss: 3.024663
# Epoch: 22 	Training Loss: 2.545069 	Validation Loss: 2.928086
# Epoch: 23 	Training Loss: 2.466921 	Validation Loss: 2.891690
# Epoch: 24 	Training Loss: 2.404856 	Validation Loss: 2.933130
# Epoch: 25 	Training Loss: 2.418853 	Validation Loss: 2.994330
# Epoch: 26 	Training Loss: 2.367775 	Validation Loss: 2.866402
# Validation loss reduced from 2.876176 to 2.866402
# Model state saved.
# Epoch: 27 	Training Loss: 2.322822 	Validation Loss: 2.904772
# Epoch: 28 	Training Loss: 2.292907 	Validation Loss: 2.816774
# Validation loss reduced from 2.866402 to 2.816774
# Model state saved.
# Epoch: 29 	Training Loss: 2.251256 	Validation Loss: 2.797674
# Validation loss reduced from 2.816774 to 2.797674
# Model state saved.
# Epoch: 30 	Training Loss: 2.257050 	Validation Loss: 2.925487
# Epoch: 31 	Training Loss: 2.143737 	Validation Loss: 2.972225
# Epoch: 32 	Training Loss: 2.117279 	Validation Loss: 2.867124
# Epoch: 33 	Training Loss: 2.129838 	Validation Loss: 2.937492
# Epoch: 34 	Training Loss: 2.099685 	Validation Loss: 2.944173
# Epoch: 35 	Training Loss: 2.025206 	Validation Loss: 2.962642
# Epoch: 36 	Training Loss: 2.020861 	Validation Loss: 2.846439
# Epoch: 37 	Training Loss: 1.990774 	Validation Loss: 2.785571
# Validation loss reduced from 2.797674 to 2.785571
# Model state saved.
# Epoch: 38 	Training Loss: 1.978464 	Validation Loss: 3.014799
# Epoch: 39 	Training Loss: 1.887914 	Validation Loss: 2.890940
# Epoch: 40 	Training Loss: 1.888313 	Validation Loss: 2.888525
# Epoch: 41 	Training Loss: 1.885665 	Validation Loss: 2.988796
# Epoch: 42 	Training Loss: 1.840360 	Validation Loss: 3.114440
# Epoch: 43 	Training Loss: 1.833585 	Validation Loss: 2.980183
# Epoch: 44 	Training Loss: 1.804754 	Validation Loss: 2.934060
# Epoch: 45 	Training Loss: 1.785821 	Validation Loss: 2.950416
# Epoch: 46 	Training Loss: 1.693125 	Validation Loss: 2.710456
# Validation loss reduced from 2.785571 to 2.710456
# Model state saved.
# Epoch: 47 	Training Loss: 1.761645 	Validation Loss: 2.819872

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Run the code cell below to try out your model on the test dataset of landmark images. Run the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 20%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    # set the module to evaluation mode
    model.eval()

    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data.item() - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Create a CNN to Classify Landmarks (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify landmarks from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Landmark Dataset
#
# Use the code cell below to create three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader): one for training data, one for validation data, and one for test data. Randomly split the images located at `landmark_images/train` to create the train and validation data loaders, and use the images located at `landmark_images/test` to create the test data loader.
#
# All three of your data loaders should be accessible via a dictionary named `loaders_transfer`. Your train data loader should be at `loaders_transfer['train']`, your validation data loader should be at `loaders_transfer['valid']`, and your test data loader should be at `loaders_transfer['test']`.
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes


### Borrowing code from CIFAR classification notebook for train-valid-test split

from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0

# how many samples per batch to load
batch_size = 10

# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Scale(256),
    transforms.CenterCrop(224), # for pytorch pre-trained models
    #transforms.Resize(400),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], # for pytorch pre-trained models
                         std=[0.229, 0.224, 0.225])
])

# Train and test datasets
train_data = LandmarksDataset('annotated_train.csv', train = True, transform=transform)
test_data  = LandmarksDataset('annotated_test.csv', train = False, transform=transform)

### Borrowing code from CIFAR classification notebook for train-valid-test split

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

loaders_transfer  = {
    'train': train_loader, 
    'valid': valid_loader, 
    'test': test_loader
}

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_transfer`, and fill in the function `get_optimizer_transfer` below.

# %%
## TODO: select loss function
criterion_transfer = nn.CrossEntropyLoss()

import torch.optim as optim

def get_optimizer_transfer(model):
    ## TODO: select and return optimizer
    return optim.SGD(model.parameters(), lr=0.005, momentum=0.9)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify images of landmarks.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
## TODO: Specify model architecture
import torchvision.models as models

model_transfer = models.resnet50(pretrained=True)

model_transfer.requires_grad_(False)
model_transfer.fc = torch.nn.Linear(2048, 50)
model_transfer.fc.requires_grad_(True)

#-#-# Do NOT modify the code below this line. #-#-#

if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 3:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# TODO: train the model and save the best model parameters at filepath 'model_transfer.pt'
n_epochs = 20

# weight initilization - default
# train the model
model_transfer = train( num_epochs, 
                       loaders_transfer, 
                       model_transfer, 
                       get_optimizer_transfer(model_transfer), 
                       criterion_transfer, 
                       use_cuda, 
                       'model_transfer.pt')


#-#-# Do NOT modify the code below this line. #-#-#

# load the model that got the best validation accuracy
model_transfer.load_state_dict(torch.load('model_transfer.pt'))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of landmark images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Write Your Landmark Prediction Algorithm
#
# Great job creating your CNN models! Now that you have put in all the hard work of creating accurate classifiers, let's define some functions to make it easy for others to use your classifiers.
#
# ### (IMPLEMENTATION) Write Your Algorithm, Part 1
#
# Implement the function `predict_landmarks`, which accepts a file path to an image and an integer k, and then predicts the **top k most likely landmarks**. You are **required** to use your transfer learned CNN from Step 2 to predict the landmarks.
#
# An example of the expected behavior of `predict_landmarks`:
# ```
# >>> predicted_landmarks = predict_landmarks('example_image.jpg', 3)
# >>> print(predicted_landmarks)
# ['Golden Gate Bridge', 'Brooklyn Bridge', 'Sydney Harbour Bridge']
# ```

# %%
import cv2
from PIL import Image

## the class names can be accessed at the `classes` attribute
## of your dataset object (e.g., `train_dataset.classes`)

def predict_landmarks(img_path, k):
    ## TODO: return the names of the top k landmarks predicted by the transfer learned CNN
    


# test on a sample image
predict_landmarks('images/test/09.Golden_Gate_Bridge/190f3bae17c32c37.jpg', 5)

# %% [markdown]
# ### (IMPLEMENTATION) Write Your Algorithm, Part 2
#
# In the code cell below, implement the function `suggest_locations`, which accepts a file path to an image as input, and then displays the image and the **top 3 most likely landmarks** as predicted by `predict_landmarks`.
#
# Some sample output for `suggest_locations` is provided below, but feel free to design your own user experience!
# ![](https://github.com/bnareyn/LandmarksClassification/blob/main/images/sample_landmark_output.png?raw=1)

# %%
def suggest_locations(img_path):
    # get landmark predictions
    predicted_landmarks = predict_landmarks(img_path, 3)
    
    ## TODO: display image and display landmark predictions

    
    

# test on a sample image
suggest_locations('images/test/09.Golden_Gate_Bridge/190f3bae17c32c37.jpg')

# %% [markdown]
# ### (IMPLEMENTATION) Test Your Algorithm
#
# Test your algorithm by running the `suggest_locations` function on at least four images on your computer. Feel free to use any images you like.
#
# __Question 4:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %%
## TODO: Execute the `suggest_locations` function on
## at least 4 images on your computer.
## Feel free to use as many code cells as needed.
